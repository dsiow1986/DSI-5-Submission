# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 4: Web Scraping Job Postings
#
# Done by: Darren Siow

# %% [markdown]
# You're working as a data scientist for a contracting firm that's rapidly expanding. Now that they have their most valuable employee (you!), they need to leverage data to win more contracts. Your firm offers technology and scientific solutions and wants to be competitive in the hiring market. Your principal has two main objectives:
#
# Determine the industry factors that are most important in predicting the salary amounts for these data.
# Determine the factors that distinguish job categories and titles from each other. For example, can required skills accurately predict job title?
# To limit the scope, your principal has suggested that you focus on data-related job postings, e.g. data scientist, data analyst, research scientist, business intelligence, and any others you might think of. You may also want to decrease the scope by limiting your search to a single region.

# %%
import time
import re
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from bs4 import BeautifulSoup
from scrapy.selector import Selector
import pandas as pd
import numpy as np

# %%
# Setting the webdriver path
webdriver_path = "C://Users/dsiow/Desktop/chromedriver_win32/chromedriver.exe"

# Set page load timeout
timeout = 6

# Creating a new Chrome session
driver = webdriver.Chrome(executable_path=webdriver_path)

# Defining the url for data scientist jobs
url = "https://www.mycareersfuture.sg/search?search=machine%20learning&sortBy=new_posting_date&page=14"

# Navigating to the webpage
driver.get(url)
time.sleep(10)

# Close the pop-up if it appears
try:
    button = driver.find_element_by_xpath('//*[@class="tr pointer OverlayNavigation__icon-cross___1wfSE"]')
    button.click()
    time.sleep(timeout)
except:
    pass

main_webpage = "https://www.mycareersfuture.sg"

# Initializing a pandas dataframe that will hold the scraped job information
df = pd.DataFrame(columns = ['title','company','employment_type','job_level','category',
                             'salary_lower','salary_upper','salary_time_interval','roles','requirements'])

# Initializing lists that will hold the scraped job information
title = []
company = []
employment_type = []
job_level = []
category = []
salary_lower = []
salary_upper = []
salary_time_interval = []
roles = []
requirements = []

# Initializing a job_card_count variable to keep track of the number of job cards scraped
job_card_count = 0

# Initializing a script_run variable that is True by default, and we be changed to False when the scraping is completed
script_run = True

while(script_run == True):
    # Selenium hands the page source to BeautifulSoup - so that BeautifulSoup can look for the JS link for each job title
    search_result_soup = BeautifulSoup(driver.page_source, 'lxml')
    result_links = search_result_soup.findAll(name='div', attrs={'class':'card relative'})
    
    # result_link contains the html content for each job card
    for result_link in result_links:

        # Finding the 'a' tag will lead us to the JavaScript element (the link that leads to more comprehensive job info)
        job_title_link = result_link.find('a')

        # Getting the link path that leads us to more comprehensive job info
        job_url = job_title_link.get('href')

        # Opening the comprehensive job info link
        sub_driver = webdriver.Chrome(executable_path=webdriver_path)
        sub_driver.get(main_webpage + job_url)

        # Sleep for a while to give the page some time to load
        time.sleep(timeout)

        # Selenium hands over the html content of the comprehensive job info page to BeautifulSoup
        job_details_soup = BeautifulSoup(sub_driver.page_source, 'lxml')

        # job_info contains information on job title, salary, company name, etc.
        job_info = job_details_soup.find('div', attrs={'class':'jobInfo'})
        
        # job_body contains information on roles & responsibilities and requirements
        job_body = job_details_soup.find('div', attrs={'class':'jobDescription w-100 v-top relative'})

        # Getting the job title, company name, employment type
        title.append(job_info.find('h1', attrs={'id':'job_title'}).text)
        company.append(job_info.find('p', attrs={'name': 'company'}).text)

        # If employment type is unavailable..
        try:
            employment_type.append(job_info.find('p', attrs={'id':'employment_type'}).text)
        except:
            employment_type.append(np.nan)

        # If job_level is unavailable..
        try:
            job_level.append(job_info.find('p', attrs={'id':'seniority'}).text)
        except:
            job_level.append(np.nan)

        # If category is unavailable..
        try:
            category.append(job_info.find('p', attrs={'id':'job-categories'}).text)
        except:
            category.append(np.nan)

        # Getting the salaries, and the salary time intervals
        # If there are undisclosed salaries...
        try:
            job_salary_raw = job_info.findAll('div', attrs={'class':'lh-solid'})[0]
        except:
            salary_lower.append(np.nan)
            salary_upper.append(np.nan)
            salary_time_interval.append(np.nan)
        else:
            # Getting the salaries
            job_salary_raw = job_info.findAll('div', attrs={'class':'lh-solid'})[0]

            # Getting the salary(lower end)
            job_salary_raw_lower = job_salary_raw.text.split('to')[0]
            job_salary_lower = int(''.join(e for e in job_salary_raw_lower if e.isalnum()))
            salary_lower.append(job_salary_lower)

            # Getting the salary(upper end)
            job_salary_raw_upper = job_salary_raw.text.split('to')[1]
            job_salary_upper = int(''.join(e for e in job_salary_raw_upper if e.isalnum()))
            salary_upper.append(job_salary_upper)

            # Getting the salary time interval
            job_salary_time_interval = job_info.find('span', attrs={'class':"salary_type dib f5 fw4 black-60 pr1 i pb"}).text
            salary_time_interval.append(job_salary_time_interval)

        # Getting the roles and responsibilities
        try:
            roles_resp = job_details_soup.find('div', {'class':'f5 fw4 black-70 lh-copy break-word'}).text
            roles.append(roles_resp)
        except:
            roles.append(np.nan)

        # Getting the requirements
        try:
            req = job_details_soup.find('div', {'id':'requirements'}).text
            requirements.append(roles_resp)
        except:
            requirements.append(np.nan)
        
        job_card_count += 1
        print('There are {} jobs scraped so far'.format(job_card_count))
        print('title {}, company {}, employment_type {}, job_level {}, category {}, salary_lower {}, salary_upper {}, \
        salary_time_interval {}, roles {}, requirements {}'.format(len(title), len(company), len(employment_type),\
                                                                  len(job_level), len(category), len(salary_lower), \
                                                                  len(salary_upper), len(salary_time_interval), len(roles),\
                                                                  len(requirements)))
        
        # Closing sub_driver
        sub_driver.close()

    if(search_result_soup.findAll("div", {"class":"tc pv3"})[0].text.find('❯') != -1):
        button = driver.find_element_by_xpath('//*[@type="action"][last()]')
        button.click()
        time.sleep(timeout)
    else:
        print('Reached end of the search result...')
        script_run = False
# Out:
# There are 1 jobs scraped so far
# title 1, company 1, employment_type 1, job_level 1, category 1, salary_lower 1, salary_upper 1,         salary_time_interval 1, roles 1, requirements 1
# There are 2 jobs scraped so far
# title 2, company 2, employment_type 2, job_level 2, category 2, salary_lower 2, salary_upper 2,         salary_time_interval 2, roles 2, requirements 2
# There are 3 jobs scraped so far
# title 3, company 3, employment_type 3, job_level 3, category 3, salary_lower 3, salary_upper 3,         salary_time_interval 3, roles 3, requirements 3
# There are 4 jobs scraped so far
# title 4, company 4, employment_type 4, job_level 4, category 4, salary_lower 4, salary_upper 4,         salary_time_interval 4, roles 4, requirements 4
# There are 5 jobs scraped so far
# title 5, company 5, employment_type 5, job_level 5, category 5, salary_lower 5, salary_upper 5,         salary_time_interval 5, roles 5, requirements 5
# There are 6 jobs scraped so far
# title 6, company 6, employment_type 6, job_level 6, category 6, salary_lower 6, salary_upper 6,         salary_time_interval 6, roles 6, requirements 6
# There are 7 jobs scraped so far
# title 7, company 7, employment_type 7, job_level 7, category 7, salary_lower 7, salary_upper 7,         salary_time_interval 7, roles 7, requirements 7
# There are 8 jobs scraped so far
# title 8, company 8, employment_type 8, job_level 8, category 8, salary_lower 8, salary_upper 8,         salary_time_interval 8, roles 8, requirements 8
# There are 9 jobs scraped so far
# title 9, company 9, employment_type 9, job_level 9, category 9, salary_lower 9, salary_upper 9,         salary_time_interval 9, roles 9, requirements 9
# There are 10 jobs scraped so far
# title 10, company 10, employment_type 10, job_level 10, category 10, salary_lower 10, salary_upper 10,         salary_time_interval 10, roles 10, requirements 10
# There are 11 jobs scraped so far
# title 11, company 11, employment_type 11, job_level 11, category 11, salary_lower 11, salary_upper 11,         salary_time_interval 11, roles 11, requirements 11
# There are 12 jobs scraped so far
# title 12, company 12, employment_type 12, job_level 12, category 12, salary_lower 12, salary_upper 12,         salary_time_interval 12, roles 12, requirements 12
# There are 13 jobs scraped so far
# title 13, company 13, employment_type 13, job_level 13, category 13, salary_lower 13, salary_upper 13,         salary_time_interval 13, roles 13, requirements 13
# There are 14 jobs scraped so far
# title 14, company 14, employment_type 14, job_level 14, category 14, salary_lower 14, salary_upper 14,         salary_time_interval 14, roles 14, requirements 14
# There are 15 jobs scraped so far
# title 15, company 15, employment_type 15, job_level 15, category 15, salary_lower 15, salary_upper 15,         salary_time_interval 15, roles 15, requirements 15
# There are 16 jobs scraped so far
# title 16, company 16, employment_type 16, job_level 16, category 16, salary_lower 16, salary_upper 16,         salary_time_interval 16, roles 16, requirements 16
# There are 17 jobs scraped so far
# title 17, company 17, employment_type 17, job_level 17, category 17, salary_lower 17, salary_upper 17,         salary_time_interval 17, roles 17, requirements 17
# There are 18 jobs scraped so far
# title 18, company 18, employment_type 18, job_level 18, category 18, salary_lower 18, salary_upper 18,         salary_time_interval 18, roles 18, requirements 18
# There are 19 jobs scraped so far
# title 19, company 19, employment_type 19, job_level 19, category 19, salary_lower 19, salary_upper 19,         salary_time_interval 19, roles 19, requirements 19
# There are 20 jobs scraped so far
# title 20, company 20, employment_type 20, job_level 20, category 20, salary_lower 20, salary_upper 20,         salary_time_interval 20, roles 20, requirements 20
# There are 21 jobs scraped so far
# title 21, company 21, employment_type 21, job_level 21, category 21, salary_lower 21, salary_upper 21,         salary_time_interval 21, roles 21, requirements 21
# There are 22 jobs scraped so far
# title 22, company 22, employment_type 22, job_level 22, category 22, salary_lower 22, salary_upper 22,         salary_time_interval 22, roles 22, requirements 22
# There are 23 jobs scraped so far
# title 23, company 23, employment_type 23, job_level 23, category 23, salary_lower 23, salary_upper 23,         salary_time_interval 23, roles 23, requirements 23
# There are 24 jobs scraped so far
# title 24, company 24, employment_type 24, job_level 24, category 24, salary_lower 24, salary_upper 24,         salary_time_interval 24, roles 24, requirements 24
# There are 25 jobs scraped so far
# title 25, company 25, employment_type 25, job_level 25, category 25, salary_lower 25, salary_upper 25,         salary_time_interval 25, roles 25, requirements 25
# There are 26 jobs scraped so far
# title 26, company 26, employment_type 26, job_level 26, category 26, salary_lower 26, salary_upper 26,         salary_time_interval 26, roles 26, requirements 26
# There are 27 jobs scraped so far
# title 27, company 27, employment_type 27, job_level 27, category 27, salary_lower 27, salary_upper 27,         salary_time_interval 27, roles 27, requirements 27
# There are 28 jobs scraped so far
# title 28, company 28, employment_type 28, job_level 28, category 28, salary_lower 28, salary_upper 28,         salary_time_interval 28, roles 28, requirements 28
# Reached end of the search result...

# %%
print(len(title))
print(len(company))
print(len(employment_type))
print(len(job_level))
print(len(category))
print(len(salary_lower))
print(len(salary_upper))
print(len(salary_time_interval))
print(len(roles))
print('-'*100)
print(len(requirements))
# Out:
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# 28
# ----------------------------------------------------------------------------------------------------
# 28

# %%
df['title'] = title
df['company'] = company
df['employment_type'] = employment_type
df['job_level'] = job_level
df['category'] = category
df['salary_lower'] = salary_lower
df['salary_upper'] = salary_upper
df['salary_time_interval'] = salary_time_interval
df['roles'] = roles
df['requirements'] = requirements

df
# Out:
#                                                 title  \
# 0                                     Research Fellow
# 1                                   AA RPA Consultant
# 2   Senior Principal Investigator  /  Principal In...
# 3                               Senior Data Scientist
# 4                  Data Sciences & Analytics Engineer
# 5                                      Data Scientist
# 6   Senior Specialist / Manager, CS Process & Project
# 7   Senior Specialist / Manager, CS Process & Project
# 8                 Program Manager, Business Integrity
# 9                            Data Scientist (JD#4567)
# 10                                     Data Scientist
# 11                                 Research Assistant
# 12  Customer Reference Marketing Manager JAPAC, Go...
# 13                                  Backend Developer
# 14                                     Data Scientist
# 15         Machine Learning- Artificial Intelliegence
# 16  Automation and Machine Learning Engineer and D...
# 17                      Software Engineer - Singapore
# 18        Dr Ian Cheong Group: Engineer (AI Research)
# 19                                     Data Scientist
# 20          Mobility Engineer Artificial Intelligence
# 21  Regional Technical Engineer - Electronic Compu...
# 22  Forensic Technology & Discovery Services Senio...
# 23  Development Lead (Assistant Director / Deputy ...
# 24                  Business Analyst (Data Analytics)
# 25  Senior Deputy Director  /  Deputy Director, Te...
# 26  School of Infocomm - Research Staff (Text Anal...
# 27  School of Infocomm - Research Staff (Data Anal...
#
#                                      company                  employment_type  \
# 0           NANYANG TECHNOLOGICAL UNIVERSITY              Contract, Full Time
# 1                          TOSS-EX PTE. LTD.                         Contract
# 2                   A*STAR RESEARCH ENTITIES              Contract, Full Time
# 3                      RESMED ASIA PTE. LTD.             Permanent, Full Time
# 4                 SINGAPORE AIRLINES LIMITED                        Permanent
# 5     ALPHATECH BUSINESS SOLUTIONS PTE. LTD.             Permanent, Full Time
# 6                            APL CO. PTE LTD                        Permanent
# 7                            APL CO. PTE LTD                        Permanent
# 8               FACEBOOK SINGAPORE PTE. LTD.                        Full Time
# 9            SCIENTE INTERNATIONAL PTE. LTD.              Contract, Full Time
# 10         DHL EXPRESS (SINGAPORE) PTE. LTD.             Permanent, Full Time
# 11          NANYANG TECHNOLOGICAL UNIVERSITY              Contract, Full Time
# 12             GOOGLE ASIA PACIFIC PTE. LTD.                        Full Time
# 13                 YOLO TECHNOLOGY PTE. LTD.                        Full Time
# 14                  COMTEL SOLUTIONS PTE LTD                         Contract
# 15                 SCHELLDEN GLOBAL SERVICES              Contract, Full Time
# 16                GOLDTECH RESOURCES PTE LTD              Permanent, Contract
# 17             GOOGLE ASIA PACIFIC PTE. LTD.                        Full Time
# 18  TEMASEK LIFE SCIENCES LABORATORY LIMITED              Contract, Full Time
# 19                        COGNOPIA PTE. LTD.  Permanent, Contract, Internship
# 20                       SMARTSOFT PTE. LTD.                        Full Time
# 21         THE SUPREME HR ADVISORY PTE. LTD.                        Full Time
# 22          ERNST & YOUNG ADVISORY PTE. LTD.                        Permanent
# 23              GOVERNMENT TECHNOLOGY AGENCY                        Permanent
# 24              GOVERNMENT TECHNOLOGY AGENCY                        Full Time
# 25                    Health Promotion Board                        Full Time
# 26                      Republic Polytechnic                         Contract
# 27                      Republic Polytechnic                         Contract
#
#                       job_level  \
# 0                  Professional
# 1                     Executive
# 2                 Non-executive
# 3              Senior Executive
# 4       Professional, Executive
# 5                  Professional
# 6              Senior Executive
# 7              Senior Executive
# 8                  Professional
# 9                  Professional
# 10                 Professional
# 11      Professional, Executive
# 12                      Manager
# 13             Senior Executive
# 14                    Executive
# 15                 Professional
# 16  Executive, Senior Executive
# 17                    Executive
# 18                    Executive
# 19             Junior Executive
# 20                 Professional
# 21             Senior Executive
# 22            Middle Management
# 23            Middle Management
# 24                 Professional
# 25            Middle Management
# 26                          NaN
# 27                          NaN
#
#                                           category  salary_lower  \
# 0                      Sciences / Laboratory / R&D        4000.0
# 1                           Information Technology        6000.0
# 2                      Sciences / Laboratory / R&D        7100.0
# 3         Engineering, Sciences / Laboratory / R&D       10000.0
# 4                           Information Technology        4000.0
# 5                           Information Technology        5500.0
# 6                                           Others        6000.0
# 7                                           Others        4500.0
# 8                             Advertising / Media         6000.0
# 9                              Banking and Finance           NaN
# 10                                          Others        4800.0
# 11                     Sciences / Laboratory / R&D        3400.0
# 12                   Marketing / Public Relations        14000.0
# 13                          Information Technology        3500.0
# 14                          Information Technology        7000.0
# 15                          Information Technology        6000.0
# 16             Engineering, Information Technology        3500.0
# 17                                     Engineering        6300.0
# 18        Engineering, Sciences / Laboratory / R&D        3000.0
# 19                          Information Technology        4500.0
# 20                          Information Technology        5800.0
# 21             Engineering, Information Technology        3000.0
# 22                                     Consulting         8000.0
# 23  Information Technology, Public / Civil Service           NaN
# 24  Information Technology, Public / Civil Service           NaN
# 25  Environment / Health  , Public / Civil Service           NaN
# 26  Education and Training, Public / Civil Service           NaN
# 27  Education and Training, Public / Civil Service        3100.0
#
#     salary_upper salary_time_interval  \
# 0         5500.0              Monthly
# 1         7500.0              Monthly
# 2        14200.0              Monthly
# 3        14000.0              Monthly
# 4         8000.0              Monthly
# 5         8000.0              Monthly
# 6         8000.0              Monthly
# 7         6000.0              Monthly
# 8        12000.0              Monthly
# 9            NaN                  NaN
# 10        6800.0              Monthly
# 11        5000.0              Monthly
# 12       28000.0              Monthly
# 13        4500.0              Monthly
# 14       10500.0              Monthly
# 15       11000.0              Monthly
# 16        7000.0              Monthly
# 17       12600.0              Monthly
# 18        4000.0              Monthly
# 19       10000.0              Monthly
# 20       11000.0              Monthly
# 21        3500.0              Monthly
# 22       16000.0              Monthly
# 23           NaN                  NaN
# 24           NaN                  NaN
# 25           NaN                  NaN
# 26           NaN                  NaN
# 27        5300.0              Monthly
#
#                                                 roles  \
# 0   There is a postdoctoral position in condensed ...
# 1    At least 1-2 years of experience on developin...
# 2   About Singapore Institute for Clinical Science...
# 3   Senior Data Scientist The Senior Data Scientis...
# 4   SIA has multiple positions for junior and seni...
# 5   ·       Use machine learning and analytical te...
# 6   BRIEF DESCRIPTION This position reports to the...
# 7   BRIEF DESCRIPTION This position reports to the...
# 8   Business Integrity's mission is to ensure safe...
# 9   An excellent opportunity to gain experience in...
# 10  If you are a dynamic team player with an entre...
# 11  A research assistant position is available in ...
# 12  Company overview: Google is not a conventional...
# 13  The incumbent is in charge of the entire back-...
# 14   Define hypotheses and identify the analysis t...
# 15  ·         Use machine learning and analytical ...
# 16  We are looking for the ideal candidate experie...
# 17  Company overview: Google is not a conventional...
# 18  Our lab in Temasek Life Sciences Laboratory is...
# 19  About Cognopia Cognopia is a leader in Sales-a...
# 20  ·         Use machine learning and analytical ...
# 21  5.5 Day A Week *9am to 6pm (Mon to Fri) *9am t...
# 22  Our innovative Forensic Technology & Discovery...
# 23  We are seeking a Development Lead to take on t...
# 24  BAF (Data Analytics) We are looking for Busine...
# 25  Strategy and Industry Engagement lead, Technol...
# 26  Responsibilities We are looking for a responsi...
# 27  Job Responsibilities We are looking for a capa...
#
#                                          requirements
# 0   There is a postdoctoral position in condensed ...
# 1    At least 1-2 years of experience on developin...
# 2   About Singapore Institute for Clinical Science...
# 3   Senior Data Scientist The Senior Data Scientis...
# 4   SIA has multiple positions for junior and seni...
# 5   ·       Use machine learning and analytical te...
# 6   BRIEF DESCRIPTION This position reports to the...
# 7   BRIEF DESCRIPTION This position reports to the...
# 8   Business Integrity's mission is to ensure safe...
# 9   An excellent opportunity to gain experience in...
# 10  If you are a dynamic team player with an entre...
# 11  A research assistant position is available in ...
# 12  Company overview: Google is not a conventional...
# 13  The incumbent is in charge of the entire back-...
# 14   Define hypotheses and identify the analysis t...
# 15  ·         Use machine learning and analytical ...
# 16  We are looking for the ideal candidate experie...
# 17  Company overview: Google is not a conventional...
# 18  Our lab in Temasek Life Sciences Laboratory is...
# 19  About Cognopia Cognopia is a leader in Sales-a...
# 20  ·         Use machine learning and analytical ...
# 21  5.5 Day A Week *9am to 6pm (Mon to Fri) *9am t...
# 22  Our innovative Forensic Technology & Discovery...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN

# %%
df.to_csv('./careersfuture_ML_part2.csv', index = False)
